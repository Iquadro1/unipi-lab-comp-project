# %%
import pickle
import src.bottleneck1 as bottleneck

# Load data from pickle file
with open('results/sphere_complexes.pkl', 'rb') as f:
    complex_res = pickle.load(f)

for sample_name in list(complex_res.keys()):
    sample_complexes = complex_res[sample_name]

    print(f"\n{'='*80}")
    print(f"ANALYZING BOTTLENECK DISTANCES FOR {sample_name.upper()}")
    print(f"{'='*80}")

    # Call the single, high-level analysis function
    title = f"Complex Similarity for {sample_name.upper()}"
    bottleneck.analyze_bottleneck_distances(sample_complexes)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# ...
# ANALYZING BOTTLENECK DISTANCES FOR SPHERE 2
# ...
#
# ...
# ANALYSIS BEFORE INFINITY CORRECTION
# ...
#
# --- COMPUTING ORIGINAL BOTTLENECK DISTANCE MATRICES ---
# (Note: Distances may be 'inf' if diagrams have unmatched infinite points)
#
# Dimension 0 Original Distance Matrix:
#
# Complex             rips              alpha             cech              delaunay_cech     delaunay_alpha    witness           relaxed_witness   strong_witness
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

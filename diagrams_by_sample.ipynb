# %%
import pickle
import src.utils as utils

# Load data from pickle file
with open('results/dragon_complexes.pkl', 'rb') as f:
    complex_res = pickle.load(f)

for sample_name in list(complex_res.keys()):

    sample_complexes = complex_res[sample_name]

    print(f"\n{'='*80}")
    print(f"PERSISTENCE DIAGRAMS FOR {sample_name.upper()}")
    print(f"{'='*80}")

    utils.plot_persistence_diagrams(sample_complexes)
# Out:
# ================================================================================
# PERSISTENCE DIAGRAMS FOR DRAGON 500
# ================================================================================
#
# Rips Complex Persistence Diagram:
# Alpha Complex Persistence Diagram:
# Alpha_inf Complex Persistence Diagram:
# Witness Complex Persistence Diagram:
# Relaxed_witness Complex Persistence Diagram:
# Strong_witness Complex Persistence Diagram:
# ================================================================================
# PERSISTENCE DIAGRAMS FOR DRAGON 1000
# ================================================================================
#
# Rips Complex Persistence Diagram:
# Alpha Complex Persistence Diagram:
# Alpha_inf Complex Persistence Diagram:
# Witness Complex Persistence Diagram:
# Relaxed_witness Complex Persistence Diagram:
# Strong_witness Complex Persistence Diagram:
# ================================================================================
# PERSISTENCE DIAGRAMS FOR DRAGON 1500
# ================================================================================
#
# Rips Complex Persistence Diagram:
# Alpha Complex Persistence Diagram:
# Alpha_inf Complex Persistence Diagram:
# Witness Complex Persistence Diagram:
# Relaxed_witness Complex Persistence Diagram:
# Strong_witness Complex Persistence Diagram:
# ================================================================================
# PERSISTENCE DIAGRAMS FOR DRAGON 2000
# ================================================================================
#
# Rips Complex Persistence Diagram:
# Alpha Complex Persistence Diagram:
# Alpha_inf Complex Persistence Diagram:
# Witness Complex Persistence Diagram:
# Relaxed_witness Complex Persistence Diagram:
# Strong_witness Complex Persistence Diagram:
# ================================================================================
# PERSISTENCE DIAGRAMS FOR DRAGON 2500
# ================================================================================
#
# Rips Complex Persistence Diagram:
# Alpha Complex Persistence Diagram:
# Alpha_inf Complex Persistence Diagram:
# Witness Complex Persistence Diagram:
# Relaxed_witness Complex Persistence Diagram:
# Strong_witness Complex Persistence Diagram:
# ================================================================================
# PERSISTENCE DIAGRAMS FOR DRAGON 3000
# ================================================================================
#
# Rips Complex Persistence Diagram:
# Alpha Complex Persistence Diagram:
# Alpha_inf Complex Persistence Diagram:
# Witness Complex Persistence Diagram:
# Relaxed_witness Complex Persistence Diagram:
# Strong_witness Complex Persistence Diagram:
# ================================================================================
# PERSISTENCE DIAGRAMS FOR DRAGON 3500
# ================================================================================
#
# Rips Complex Persistence Diagram:
# Alpha Complex Persistence Diagram:
# Alpha_inf Complex Persistence Diagram:
# Witness Complex Persistence Diagram:
# Relaxed_witness Complex Persistence Diagram:
# Strong_witness Complex Persistence Diagram:
# ================================================================================
# PERSISTENCE DIAGRAMS FOR DRAGON 4000
# ================================================================================
#
# Rips Complex Persistence Diagram:
# Alpha Complex Persistence Diagram:
# Alpha_inf Complex Persistence Diagram:
# Witness Complex Persistence Diagram:
# Relaxed_witness Complex Persistence Diagram:
# Strong_witness Complex Persistence Diagram:
